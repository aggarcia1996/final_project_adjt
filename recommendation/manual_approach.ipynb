# %%
# Import Libraries
# =========================================================

import numpy as np
import pandas as pd
from collections import Counter
import itertools
from itertools import product
import itertools
import warnings

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.animation import FuncAnimation
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import plotly.offline as pyo
from heatmap import heatmap, corrplot

from sklearn.preprocessing import MinMaxScaler, StandardScaler

## GLOBAL SETTINGS
pd.set_option("display.max_columns", None)
pd.options.mode.chained_assignment = None 
warnings.filterwarnings("ignore")
# %matplotlib inline
plt.style.use("ggplot")
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option("display.max_rows", 500)
plt.rcParams["savefig.bbox"] = "tight"

# %% [markdown]
# ### BEST CUSTOMERS (manual assessment)
#
# init plan:
# 1. check customers that brought in the most revenue, assuming each active product per month returns a monthly profit.
# 2. categorize customers into none, low, mid, high, premium
# 3. check retention and churn rates per product per revenue class
# 4. filter for highest retention, lowest churn and highest revenue class
# 5. see if it's required to add more dimensions (age, region etc)

# %%
df = pd.read_csv("Bobs_df_semi_clean.csv")
df.drop("Unnamed: 0", axis = 1, inplace = True)
df["pk_partition"] = pd.to_datetime(df["pk_partition"])
df["entry_date"] = pd.to_datetime(df["entry_date"])
df["pk_cid"] = df["pk_cid"].astype(str)

# %%
product_revenue_map = {"short_term_deposit": 60, "loans": 40, "mortgage": 40, "funds": 60, "securities": 60, "long_term_deposit": 60, "credit_card": 40, "pension_plan": 60, "payroll_account": 10, "emc_account": 10, "debit_card": 40, "em_account_p": 10, "em_acount": 10}
products = list(product_revenue_map.keys())

df_product = df[products]
revenues = np.array([product_revenue_map[f] for f in products])
df['total_revenue'] = (df_product * revenues).sum(axis=1)
df_user_revenue = df.groupby('pk_cid')['total_revenue'].sum().reset_index()
df = pd.merge(df, df_user_revenue, on='pk_cid', how='left')

# %%
df.rename(columns = {"total_revenue_x": "revenue_month", "total_revenue_y": "revenue_total"}, inplace = True)

# %%
df[df["revenue_total"] == 850]
# Out:
#           pk_cid pk_partition country_id  Male  age  deceased     salary  \
# 62       1050636   2018-01-28         ES     1   23         0 136,930.23
# 364      1050254   2018-01-28         ES     0   22         0  93,290.43
# 372      1050266   2018-01-28         ES     1   37         0 128,014.47
# 527      1050455   2018-01-28         ES     1   57         0 108,421.98
# 581      1050384   2018-01-28         ES     1   30         0  67,345.95
# ...          ...          ...        ...   ...  ...       ...        ...
# 5962512  1167004   2019-05-28         ES     0   46         0  82,570.86
# 5962649  1167054   2019-05-28         ES     1   38         0 139,758.90
# 5962676  1167103   2019-05-28         ES     0   34         0        NaN
# 5962872  1166753   2019-05-28         ES     1   22         0  86,137.50
# 5962875  1166750   2019-05-28         ES     1   22         0  55,584.90
#
#          short_term_deposit  loans  mortgage  funds  securities  \
# 62                        0      0         0      0           0
# 364                       0      0         0      0           0
# 372                       0      0         0      0           0
# 527                       0      0         0      0           0
# 581                       0      0         0      0           0
# ...                     ...    ...       ...    ...         ...
# 5962512                   0      0         0      0           0
# 5962649                   0      0         0      0           0
# 5962676                   0      0         0      0           0
# 5962872                   0      0         0      0           0
# 5962875                   0      0         0      0           0
#
#          long_term_deposit  em_account_pp  credit_card  payroll  pension_plan  \
# 62                       0              0            0        0             0
# 364                      0              0            0        0             0
# 372                      0              0            0        0             0
# 527                      0              0            0        0             0
# 581                      0              0            0        0             0
# ...                    ...            ...          ...      ...           ...
# 5962512                  0              0            0        0             0
# 5962649                  0              0            0        0             0
# 5962676                  0              0            0        0             0
# 5962872                  0              0            0        1             1
# 5962875                  0              0            0        0             0
#
#          payroll_account  emc_account  debit_card  em_account_p  em_acount  \
# 62                     0            0           1             0          1
# 364                    0            0           1             0          1
# 372                    0            0           1             0          1
# 527                    0            0           1             0          1
# 581                    0            0           1             0          1
# ...                  ...          ...         ...           ...        ...
# 5962512                0            0           1             0          1
# 5962649                0            0           1             0          1
# 5962676                0            0           1             0          1
# 5962872                1            0           1             0          0
# 5962875                0            0           1             0          1
#
#         entry_date entry_channel  active_customer  segment  salary_LN  \
# 62      2015-08-10           KHE                1  student      11.83
# 364     2015-08-10           KHD                1  student      11.44
# 372     2015-08-10           KHE                1  regular      11.76
# 527     2015-08-10           KAT                1  regular      11.59
# 581     2015-08-10           KHE                1  student      11.12
# ...            ...           ...              ...      ...        ...
# 5962512 2016-08-16           KFC                1  regular      11.32
# 5962649 2016-08-16           KFC                1  regular      11.85
# 5962676 2016-08-16           KFC                1  regular        NaN
# 5962872 2016-08-14           KHE                1  student      11.36
# 5962875 2016-08-14           KHE                1  student      10.93
#
#             region  revenue_month  revenue_total
# 62       Cantabria             50            850
# 364       Albacete             50            850
# 372         Toledo             50            850
# 527         Madrid             50            850
# 581         Toledo             50            850
# ...            ...            ...            ...
# 5962512  La Coruna             50            850
# 5962649   Asturias             50            850
# 5962676    Cordoba             50            850
# 5962872     Burgos            110            850
# 5962875    Almeria             50            850
#
# [80527 rows x 30 columns]

# %%
df[df["pk_cid"] == "1166750"]
# Out:
#           pk_cid pk_partition country_id  Male  age  deceased    salary  \
# 167821   1166750   2018-01-28         ES     1   21         0 55,584.90
# 314120   1166750   2018-02-28         ES     1   21         0 55,584.90
# 531726   1166750   2018-03-28         ES     1   21         0 55,584.90
# 775767   1166750   2018-04-28         ES     1   21         0 55,584.90
# 1174216  1166750   2018-05-28         ES     1   21         0 55,584.90
# 1426430  1166750   2018-06-28         ES     1   21         0 55,584.90
# 1536964  1166750   2018-07-28         ES     1   21         0 55,584.90
# 2161405  1166750   2018-08-28         ES     1   22         0 55,584.90
# 2392337  1166750   2018-09-28         ES     1   22         0 55,584.90
# 2647306  1166750   2018-10-28         ES     1   22         0 55,584.90
# 3097841  1166750   2018-11-28         ES     1   22         0 55,584.90
# 3606549  1166750   2018-12-28         ES     1   22         0 55,584.90
# 4013525  1166750   2019-01-28         ES     1   22         0 55,584.90
# 4576634  1166750   2019-02-28         ES     1   22         0 55,584.90
# 4904683  1166750   2019-03-28         ES     1   22         0 55,584.90
# 5201012  1166750   2019-04-28         ES     1   22         0 55,584.90
# 5962875  1166750   2019-05-28         ES     1   22         0 55,584.90
#
#          short_term_deposit  loans  mortgage  funds  securities  \
# 167821                    0      0         0      0           0
# 314120                    0      0         0      0           0
# 531726                    0      0         0      0           0
# 775767                    0      0         0      0           0
# 1174216                   0      0         0      0           0
# 1426430                   0      0         0      0           0
# 1536964                   0      0         0      0           0
# 2161405                   0      0         0      0           0
# 2392337                   0      0         0      0           0
# 2647306                   0      0         0      0           0
# 3097841                   0      0         0      0           0
# 3606549                   0      0         0      0           0
# 4013525                   0      0         0      0           0
# 4576634                   0      0         0      0           0
# 4904683                   0      0         0      0           0
# 5201012                   0      0         0      0           0
# 5962875                   0      0         0      0           0
#
#          long_term_deposit  em_account_pp  credit_card  payroll  pension_plan  \
# 167821                   0              0            0        0             0
# 314120                   0              0            0        0             0
# 531726                   0              0            0        0             0
# 775767                   0              0            0        0             0
# 1174216                  0              0            0        0             0
# 1426430                  0              0            0        0             0
# 1536964                  0              0            0        0             0
# 2161405                  0              0            0        0             0
# 2392337                  0              0            0        0             0
# 2647306                  0              0            0        0             0
# 3097841                  0              0            0        0             0
# 3606549                  0              0            0        0             0
# 4013525                  0              0            0        0             0
# 4576634                  0              0            0        0             0
# 4904683                  0              0            0        0             0
# 5201012                  0              0            0        0             0
# 5962875                  0              0            0        0             0
#
#          payroll_account  emc_account  debit_card  em_account_p  em_acount  \
# 167821                 0            0           1             0          1
# 314120                 0            0           1             0          1
# 531726                 0            0           1             0          1
# 775767                 0            0           1             0          1
# 1174216                0            0           1             0          1
# 1426430                0            0           1             0          1
# 1536964                0            0           1             0          1
# 2161405                0            0           1             0          1
# 2392337                0            0           1             0          1
# 2647306                0            0           1             0          1
# 3097841                0            0           1             0          1
# 3606549                0            0           1             0          1
# 4013525                0            0           1             0          1
# 4576634                0            0           1             0          1
# 4904683                0            0           1             0          1
# 5201012                0            0           1             0          1
# 5962875                0            0           1             0          1
#
#         entry_date entry_channel  active_customer  segment  salary_LN  \
# 167821  2016-08-14           KHE                1  student      10.93
# 314120  2016-08-14           KHE                1  student      10.93
# 531726  2016-08-14           KHE                1  student      10.93
# 775767  2016-08-14           KHE                1  student      10.93
# 1174216 2016-08-14           KHE                1  student      10.93
# 1426430 2016-08-14           KHE                1  student      10.93
# 1536964 2016-08-14           KHE                1  student      10.93
# 2161405 2016-08-14           KHE                1  student      10.93
# 2392337 2016-08-14           KHE                1  student      10.93
# 2647306 2016-08-14           KHE                1  student      10.93
# 3097841 2016-08-14           KHE                1  student      10.93
# 3606549 2016-08-14           KHE                1  student      10.93
# 4013525 2016-08-14           KHE                1  student      10.93
# 4576634 2016-08-14           KHE                1  student      10.93
# 4904683 2016-08-14           KHE                1  student      10.93
# 5201012 2016-08-14           KHE                1  student      10.93
# 5962875 2016-08-14           KHE                1  student      10.93
#
#           region  revenue_month  revenue_total
# 167821   Almeria             50            850
# 314120   Almeria             50            850
# 531726   Almeria             50            850
# 775767   Almeria             50            850
# 1174216  Almeria             50            850
# 1426430  Almeria             50            850
# 1536964  Almeria             50            850
# 2161405  Almeria             50            850
# 2392337  Almeria             50            850
# 2647306  Almeria             50            850
# 3097841  Almeria             50            850
# 3606549  Almeria             50            850
# 4013525  Almeria             50            850
# 4576634  Almeria             50            850
# 4904683  Almeria             50            850
# 5201012  Almeria             50            850
# 5962875  Almeria             50            850

# %%
df.groupby("pk_cid")["revenue_total"].min().plot(kind = "hist", bins = 200)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
revenue_classes_dict = {
    "None": (-1, 0),
    "Micro": (1, 50),
    "Low": (51, 169),    
    "170": (170, 170.1),    
    "mid": (171, 849),
    "850": (850, 850.1),
    "upper": (851, 1200),
    "high": (1201, 2000),
    "VIP": (2001, 10000)}

df["revenue_class"] = df["revenue_total"].apply(
    lambda x: next(
    (cat for cat, range in revenue_classes_dict.items() if range[0] <= x <= range[1])))

# %%
revenue_class_summary = df.groupby("revenue_class")["pk_cid"].nunique().sort_values(ascending = False)
print(revenue_class_summary)
revenue_class_summary.plot(kind = "bar")
# Out:
# revenue_class
# 170      167585
# None     105989
# Low       79482
# mid       54873
# Micro     20457
# upper     10212
# high       9865
# 850        4769
# VIP        3141
# Name: pk_cid, dtype: int64
# <AxesSubplot:xlabel='revenue_class'>

# %%
user_revenue = df.groupby(["pk_cid", "revenue_class"])["revenue_total"].min().reset_index()

revenue_per_class = user_revenue.groupby("revenue_class")["revenue_total"].sum().reset_index()
revenue_per_class.sort_values("revenue_total", ascending = False, inplace = True)
revenue_per_class.plot(kind = "bar", x = "revenue_class", y = "revenue_total")
# Out:
# <AxesSubplot:xlabel='revenue_class'>

# %% [markdown]
# ## Thoughts SO FAR
# - main income source are 170 (users with just active EM_ACCOUNT over 17 month)
# - second main income comes from mid (170-849 revenue). Might be able to learn a lot from this group as it comes with a lot of data observations and a lot of variance in products and retention
# - 850 may be worth a look as well, EM_ACCOUNT + DEBIT_CARD Over 17 month uninterrupted. ~4800 users

# %%
def check_rev_group(group):
    temp = df[df["revenue_class"] == group]
    print(temp.groupby("pk_cid")[products].mean().mean().sort_values(ascending = False) * 100)
    (temp.groupby("pk_cid")[products].mean().mean().sort_values(ascending = False) * 100).plot(kind = "bar")

# %%
check_rev_group("mid")
# Out:
# em_acount            75.08
# debit_card           32.10
# emc_account          15.81
# payroll_account      13.57
# pension_plan          7.37
# long_term_deposit     3.91
# short_term_deposit    2.02
# credit_card           1.65
# securities            0.50
# funds                 0.24
# loans                 0.01
# mortgage              0.00
# em_account_p          0.00
# dtype: float64

# %% [markdown]
# ### revenue segment generalization

# %%
revenue_classes = ["Micro", "Low", "170", "mid", "850", "upper", "high", "VIP"]

results_dict_ = {}
for rev_class in revenue_classes:
    rev_class_df = df[df["revenue_class"] == rev_class]
    avg_retention = rev_class_df.groupby("pk_cid")[products].sum().mean().sort_values(ascending = False)
    results_dict_[rev_class] = avg_retention
avg_retention = pd.DataFrame(results_dict_)

avg_retention.style.background_gradient(axis = None) ## Shows the average retention rate for each product for each revenue class
# Out:
# <style type="text/css">
# #T_e6374_row0_col0, #T_e6374_row0_col1, #T_e6374_row0_col2, #T_e6374_row1_col0, #T_e6374_row1_col2, #T_e6374_row2_col0, #T_e6374_row2_col1, #T_e6374_row2_col2, #T_e6374_row2_col3, #T_e6374_row2_col4, #T_e6374_row2_col5, #T_e6374_row2_col6, #T_e6374_row2_col7, #T_e6374_row5_col0, #T_e6374_row5_col1, #T_e6374_row5_col2, #T_e6374_row5_col3, #T_e6374_row5_col4, #T_e6374_row6_col0, #T_e6374_row6_col1, #T_e6374_row6_col2, #T_e6374_row6_col3, #T_e6374_row6_col4, #T_e6374_row6_col5, #T_e6374_row6_col6, #T_e6374_row7_col0, #T_e6374_row7_col1, #T_e6374_row7_col2, #T_e6374_row8_col0, #T_e6374_row8_col1, #T_e6374_row8_col2, #T_e6374_row8_col3, #T_e6374_row8_col4, #T_e6374_row8_col5, #T_e6374_row8_col6, #T_e6374_row9_col0, #T_e6374_row9_col2, #T_e6374_row10_col0, #T_e6374_row10_col1, #T_e6374_row10_col2, #T_e6374_row11_col0, #T_e6374_row11_col1, #T_e6374_row11_col2, #T_e6374_row11_col3, #T_e6374_row11_col4, #T_e6374_row12_col0, #T_e6374_row12_col1, #T_e6374_row12_col2, #T_e6374_row12_col4, #T_e6374_row12_col6, #T_e6374_row12_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e6374_row0_col3, #T_e6374_row4_col1, #T_e6374_row4_col2, #T_e6374_row10_col4, #T_e6374_row12_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e6374_row0_col4, #T_e6374_row4_col0, #T_e6374_row7_col4, #T_e6374_row12_col5 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_e6374_row0_col5, #T_e6374_row9_col4, #T_e6374_row10_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e6374_row0_col6, #T_e6374_row7_col6 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_e6374_row0_col7 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_e6374_row1_col1, #T_e6374_row4_col4, #T_e6374_row6_col7, #T_e6374_row8_col7, #T_e6374_row9_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e6374_row1_col3 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_e6374_row1_col4 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_e6374_row1_col5 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_e6374_row1_col6 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_e6374_row1_col7 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_e6374_row3_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_e6374_row3_col1 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_e6374_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e6374_row3_col3 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_e6374_row3_col4 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_e6374_row3_col5 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_e6374_row3_col6 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_e6374_row3_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_e6374_row4_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_e6374_row4_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_e6374_row4_col6 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_e6374_row4_col7 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_e6374_row5_col5, #T_e6374_row7_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_e6374_row5_col6, #T_e6374_row11_col5 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_e6374_row5_col7 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_e6374_row7_col5, #T_e6374_row7_col7 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_e6374_row9_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_e6374_row9_col5 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_e6374_row9_col6 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_e6374_row9_col7 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_e6374_row10_col5 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_e6374_row10_col6 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_e6374_row10_col7 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_e6374_row11_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_e6374_row11_col7 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# </style>
# <table id="T_e6374">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6374_level0_col0" class="col_heading level0 col0" >Micro</th>
#       <th id="T_e6374_level0_col1" class="col_heading level0 col1" >Low</th>
#       <th id="T_e6374_level0_col2" class="col_heading level0 col2" >170</th>
#       <th id="T_e6374_level0_col3" class="col_heading level0 col3" >mid</th>
#       <th id="T_e6374_level0_col4" class="col_heading level0 col4" >850</th>
#       <th id="T_e6374_level0_col5" class="col_heading level0 col5" >upper</th>
#       <th id="T_e6374_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_e6374_level0_col7" class="col_heading level0 col7" >VIP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6374_level0_row0" class="row_heading level0 row0" >credit_card</th>
#       <td id="T_e6374_row0_col0" class="data row0 col0" >0.002737</td>
#       <td id="T_e6374_row0_col1" class="data row0 col1" >0.006643</td>
#       <td id="T_e6374_row0_col2" class="data row0 col2" >0.000090</td>
#       <td id="T_e6374_row0_col3" class="data row0 col3" >0.239116</td>
#       <td id="T_e6374_row0_col4" class="data row0 col4" >0.158524</td>
#       <td id="T_e6374_row0_col5" class="data row0 col5" >0.768508</td>
#       <td id="T_e6374_row0_col6" class="data row0 col6" >2.225443</td>
#       <td id="T_e6374_row0_col7" class="data row0 col7" >8.464820</td>
#     </tr>
#     <tr>
#       <th id="T_e6374_level0_row1" class="row_heading level0 row1" >debit_card</th>
#       <td id="T_e6374_row1_col0" class="data row1 col0" >0.012514</td>
#       <td id="T_e6374_row1_col1" class="data row1 col1" >0.085604</td>
#       <td id="T_e6374_row1_col2" class="data row1 col2" >0.008963</td>
#       <td id="T_e6374_row1_col3" class="data row1 col3" >4.422576</td>
#       <td id="T_e6374_row1_col4" class="data row1 col4" >16.209897</td>
#       <td id="T_e6374_row1_col5" class="data row1 col5" >7.082452</td>
#       <td id="T_e6374_row1_col6" class="data row1 col6" >11.863254</td>
#       <td id="T_e6374_row1_col7" class="data row1 col7" >14.347023</td>
#     </tr>
#     <tr>
#       <th id="T_e6374_level0_row2" class="row_heading level0 row2" >em_account_p</th>
#       <td id="T_e6374_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_e6374_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_e6374_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_e6374_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_e6374_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_e6374_row2_col5" class="data row2 col5" >0.001665</td>
#       <td id="T_e6374_row2_col6" class="data row2 col6" >0.001723</td>
#       <td id="T_e6374_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6374_level0_row3" class="row_heading level0 row3" >em_acount</th>
#       <td id="T_e6374_row3_col0" class="data row3 col0" >2.568656</td>
#       <td id="T_e6374_row3_col1" class="data row3 col1" >8.684784</td>
#       <td id="T_e6374_row3_col2" class="data row3 col2" >16.675729</td>
#       <td id="T_e6374_row3_col3" class="data row3 col3" >11.157454</td>
#       <td id="T_e6374_row3_col4" class="data row3 col4" >15.980918</td>
#       <td id="T_e6374_row3_col5" class="data row3 col5" >8.969644</td>
#       <td id="T_e6374_row3_col6" class="data row3 col6" >5.181956</td>
#       <td id="T_e6374_row3_col7" class="data row3 col7" >4.137217</td>
#     </tr>
#     <tr>
#       <th id="T_e6374_level0_row4" class="row_heading level0 row4" >emc_account</th>
#       <td id="T_e6374_row4_col0" class="data row4 col0" >0.159554</td>
#       <td id="T_e6374_row4_col1" class="data row4 col1" >0.269986</td>
#       <td id="T_e6374_row4_col2" class="data row4 col2" >0.246854</td>
#       <td id="T_e6374_row4_col3" class="data row4 col3" >2.470578</td>
#       <td id="T_e6374_row4_col4" class="data row4 col4" >0.101279</td>
#       <td id="T_e6374_row4_col5" class="data row4 col5" >4.302585</td>
#       <td id="T_e6374_row4_col6" class="data row4 col6" >5.040041

# %%
results_dict = {}
for rev_class in revenue_classes:
    rev_class_df = df[df["revenue_class"] == rev_class]
    avg_had_product = (rev_class_df.groupby("pk_cid")[products].mean().mean() * 100).sort_values(ascending = False)
    results_dict[rev_class] = avg_had_product
avg_had_product = pd.DataFrame(results_dict)

avg_had_product.style.background_gradient(axis = None) ## Shows how many people in each revenue class had each product at least once on average (in %)
# Out:
# <style type="text/css">
# #T_0cfa0_row0_col0, #T_0cfa0_row0_col1, #T_0cfa0_row0_col2, #T_0cfa0_row1_col2, #T_0cfa0_row2_col0, #T_0cfa0_row2_col1, #T_0cfa0_row2_col2, #T_0cfa0_row2_col3, #T_0cfa0_row2_col4, #T_0cfa0_row2_col5, #T_0cfa0_row2_col6, #T_0cfa0_row2_col7, #T_0cfa0_row5_col0, #T_0cfa0_row5_col1, #T_0cfa0_row5_col2, #T_0cfa0_row5_col3, #T_0cfa0_row5_col4, #T_0cfa0_row6_col0, #T_0cfa0_row6_col1, #T_0cfa0_row6_col2, #T_0cfa0_row6_col3, #T_0cfa0_row6_col4, #T_0cfa0_row6_col5, #T_0cfa0_row6_col6, #T_0cfa0_row7_col0, #T_0cfa0_row7_col1, #T_0cfa0_row7_col2, #T_0cfa0_row8_col0, #T_0cfa0_row8_col1, #T_0cfa0_row8_col2, #T_0cfa0_row8_col3, #T_0cfa0_row8_col4, #T_0cfa0_row8_col5, #T_0cfa0_row8_col6, #T_0cfa0_row9_col2, #T_0cfa0_row10_col0, #T_0cfa0_row10_col2, #T_0cfa0_row11_col0, #T_0cfa0_row11_col1, #T_0cfa0_row11_col2, #T_0cfa0_row11_col4, #T_0cfa0_row12_col0, #T_0cfa0_row12_col1, #T_0cfa0_row12_col2, #T_0cfa0_row12_col4, #T_0cfa0_row12_col6, #T_0cfa0_row12_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0cfa0_row0_col3, #T_0cfa0_row1_col1, #T_0cfa0_row4_col2, #T_0cfa0_row7_col4, #T_0cfa0_row9_col1, #T_0cfa0_row10_col4, #T_0cfa0_row12_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_0cfa0_row0_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_0cfa0_row0_col5, #T_0cfa0_row9_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_0cfa0_row0_col6, #T_0cfa0_row7_col6 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_0cfa0_row0_col7 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_0cfa0_row1_col0, #T_0cfa0_row4_col4, #T_0cfa0_row6_col7, #T_0cfa0_row8_col7, #T_0cfa0_row9_col0, #T_0cfa0_row10_col1, #T_0cfa0_row11_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_0cfa0_row1_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_0cfa0_row1_col4 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_0cfa0_row1_col5 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_0cfa0_row1_col6 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_0cfa0_row1_col7 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_0cfa0_row3_col0 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_0cfa0_row3_col1 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_0cfa0_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0cfa0_row3_col3 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_0cfa0_row3_col4 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_0cfa0_row3_col5 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_0cfa0_row3_col6 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_0cfa0_row3_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_0cfa0_row4_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_0cfa0_row4_col1, #T_0cfa0_row12_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_0cfa0_row4_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_0cfa0_row4_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_0cfa0_row4_col6 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_0cfa0_row4_col7 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_0cfa0_row5_col5 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_0cfa0_row5_col6, #T_0cfa0_row7_col3, #T_0cfa0_row11_col5, #T_0cfa0_row11_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_0cfa0_row5_col7, #T_0cfa0_row9_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_0cfa0_row7_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_0cfa0_row7_col7, #T_0cfa0_row10_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_0cfa0_row9_col5 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_0cfa0_row9_col6 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_0cfa0_row9_col7 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_0cfa0_row10_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_0cfa0_row10_col6 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_0cfa0_row10_col7 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_0cfa0_row11_col7 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# </style>
# <table id="T_0cfa0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cfa0_level0_col0" class="col_heading level0 col0" >Micro</th>
#       <th id="T_0cfa0_level0_col1" class="col_heading level0 col1" >Low</th>
#       <th id="T_0cfa0_level0_col2" class="col_heading level0 col2" >170</th>
#       <th id="T_0cfa0_level0_col3" class="col_heading level0 col3" >mid</th>
#       <th id="T_0cfa0_level0_col4" class="col_heading level0 col4" >850</th>
#       <th id="T_0cfa0_level0_col5" class="col_heading level0 col5" >upper</th>
#       <th id="T_0cfa0_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_0cfa0_level0_col7" class="col_heading level0 col7" >VIP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cfa0_level0_row0" class="row_heading level0 row0" >credit_card</th>
#       <td id="T_0cfa0_row0_col0" class="data row0 col0" >0.047490</td>
#       <td id="T_0cfa0_row0_col1" class="data row0 col1" >0.100634</td>
#       <td id="T_0cfa0_row0_col2" class="data row0 col2" >0.001227</td>
#       <td id="T_0cfa0_row0_col3" class="data row0 col3" >1.653307</td>
#       <td id="T_0cfa0_row0_col4" class="data row0 col4" >0.952462</td>
#       <td id="T_0cfa0_row0_col5" class="data row0 col5" >4.743189</td>
#       <td id="T_0cfa0_row0_col6" class="data row0 col6" >13.277643</td>
#       <td id="T_0cfa0_row0_col7" class="data row0 col7" >49.861050</td>
#     </tr>
#     <tr>
#       <th id="T_0cfa0_level0_row1" class="row_heading level0 row1" >debit_card</th>
#       <td id="T_0cfa0_row1_col0" class="data row1 col0" >0.476729</td>
#       <td id="T_0cfa0_row1_col1" class="data row1 col1" >1.738583</td>
#       <td id="T_0cfa0_row1_col2" class="data row1 col2" >0.147162</td>
#       <td id="T_0cfa0_row1_col3" class="data row1 col3" >32.099646</td>
#       <td id="T_0cfa0_row1_col4" class="data row1 col4" >95.567572</td>
#       <td id="T_0cfa0_row1_col5" class="data row1 col5" >43.528450</td>
#       <td id="T_0cfa0_row1_col6" class="data row1 col6" >70.695156</td>
#       <td id="T_0cfa0_row1_col7" class="data row1 col7" >84.574186</td>
#     </tr>
#     <tr>
#       <th id="T_0cfa0_level0_row2" class="row_heading level0 row2" >em_account_p</th>
#       <td id="T_0cfa0_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_0cfa0_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_0cfa0_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_0cfa0_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_0cfa0_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_0cfa0_row2_col5" class="data row2 col5" >0.009792</td>
#       <td id="T_0cfa0_row2_col6" class="data row2 col6" >0.010137</td>
#       <td id="T_0cfa0_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cfa0_level0_row3" class="row_heading level0 row3" >em_acount</th>
#       <td id="T_0cfa0_row3_col0" class="data row3 col0" >60.970262</td>
#       <td id="T_0cfa0_row3_col1" class="data row3 col1" >91.680974</td>
#       <td id="T_0cfa0_row3_col2" class="data row3 col2" >98.295460</td>
#       <td id="T_0cfa0_row3_col3" class="data row3 col3" >75.081762</td>
#       <td id="T_0cfa0_row3_col4" class="data row3 col4" >94.341762</td>
#       <td id="T_0cfa0_row3_col5" class="data row3 col5" >54.295342</td>
#       <td id="T_0cfa0_row3_col6" class="data row3 col6" >30.872119</td>
#       <td id="T_0cfa0_row3_col7" class="data row3 col7" >24.411508</td>
#     </tr>
#     <tr>
#       <th id="T_0cfa0_level0_row4" class="row_heading level0 row4" >emc_account</th>
#       <td id="T_0cfa0_row4_col0" class="data row4 col0" >2.355280</td>
#       <td id="T_0cfa0_row4_col1" class="data row4 col1" >2.290193</td>
#       <td id="T_0cfa0_row4_col2" class="data row4 col2" >1.463938</td>
#       <td id="T_0cfa0_row4_col3" class="data row4 col3" >15.813129</td>
#       <td id="T_0cfa0_row4_col4" class="data row4 col4" >0.642435</td>
#       <td id="T_0cfa0_row4_col5" class="data row4 col5" >25.837242</td>

# %%
def retention_vs_had_prod(product):
    product_avg = avg_had_product.loc[product]
    product_results = avg_retention.loc[product]

    fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
    sns.lineplot(x=product_avg.index, y=product_avg.values, ax=axs[0])
    axs[0].set_ylabel(f"Average % of people who had product")
    axs[0].set_title(f"{product}\nAverage % of people who had product")
    sns.lineplot(x=product_results.index, y=product_results.values, ax=axs[1])
    axs[1].set_ylabel(f"Average retention for {product} in months")
    axs[1].set_title(f"Retention by revenue class in months")
    fig.tight_layout(pad=2)
    plt.show()

# %%
for prod in products:
    retention_vs_had_prod(prod)

# %%
avg_had_product
avg_retention

# %%
best_prod = avg_had_product[["upper", "high", "VIP"]]
avg_had_product_best = best_prod[best_prod.gt(30).any(axis = 1)]
avg_had_product_best
# Out:
#                  upper  high   VIP
# credit_card       4.74 13.28 49.86
# debit_card       43.53 70.70 84.57
# em_acount        54.30 30.87 24.41
# emc_account      25.84 29.89 58.46
# payroll_account  35.50 67.77 80.50
# pension_plan     22.98 55.51 75.49

# %%
best_prod_ = avg_retention[["upper", "high", "VIP"]]
avg_retention_best = best_prod_[best_prod_.gt(5).any(axis = 1)]
avg_retention_best
# Out:
#                  upper  high   VIP
# credit_card       0.77  2.23  8.46
# debit_card        7.08 11.86 14.35
# em_acount         8.97  5.18  4.14
# emc_account       4.30  5.04  9.92
# payroll_account   5.73 11.38 13.66
# pension_plan      3.62  9.30 12.80

# %%
best_upper_plus_products = list(avg_retention_best.index)
best_upper_plus_products
# Out:
# ['credit_card',
#  'debit_card',
#  'em_acount',
#  'emc_account',
#  'payroll_account',
#  'pension_plan']

# %%
def cooccurrence_calculator(data, subset, sub_value, product_list, combinations):
    data = data[data[subset] == sub_value]
    data = data[product_list + ["pk_cid", "pk_partition"]]
    unique_customers = data["pk_cid"].unique()
    print(f"Number of unique customers: {len(unique_customers)}")
    cooccurrence_dict = {}
    for pair in itertools.combinations(product_list, combinations):
        cooccurrence_dict[pair] = {"count": 0, "cooccurrence": 0}

    for cid in unique_customers:
        customer_df = data[data["pk_cid"] == cid]
        customer_prod_df = customer_df.groupby("pk_partition")[product_list].sum()
        for pair in itertools.combinations(product_list, combinations):
            pair_count = (customer_prod_df[list(pair)].sum(axis = 1) == len(pair)).sum()
            cooccurrence_dict[pair]["count"] += (pair_count > 0)
            cooccurrence_dict[pair]["cooccurrence"] += pair_count
        
    cooccurrence_means = {k: v["count"] / len(unique_customers) if v["count"] > 0 else 0 for k, v in cooccurrence_dict.items()}
    cooccurrence_counts = {k: v["count"] for k, v in cooccurrence_dict.items()}
    
    cooccurrence_df = pd.DataFrame.from_dict(cooccurrence_means, orient = "index", columns = ["mean_cooccurrence"])
    cooccurrence_df["user_count"] = pd.Series(cooccurrence_counts)
    cooccurrence_df.index.name = "product_pairs"
    cooccurrence_df.sort_values("mean_cooccurrence", ascending = False, inplace = True)
    
    return cooccurrence_df

# %%
madridians = df[df["region"] == "Madrid"]
cooc_vip_madrid = cooccurrence_calculator(
    madridians, "revenue_class", "VIP", best_upper_plus_products, 5)
cooc_vip_madrid.head(10)
# Out:
# Number of unique customers: 1377
#                                                     mean_cooccurrence  \
# product_pairs
# (credit_card, debit_card, emc_account, payroll_...               0.38
# (credit_card, debit_card, em_acount, payroll_ac...               0.07
# (debit_card, em_acount, emc_account, payroll_ac...               0.07
# (credit_card, debit_card, em_acount, emc_accoun...               0.06
# (credit_card, debit_card, em_acount, emc_accoun...               0.05
# (credit_card, em_acount, emc_account, payroll_a...               0.05
#
#                                                     user_count
# product_pairs
# (credit_card, debit_card, emc_account, payroll_...         530
# (credit_card, debit_card, em_acount, payroll_ac...         100
# (debit_card, em_acount, emc_account, payroll_ac...          95
# (credit_card, debit_card, em_acount, emc_accoun...          76
# (credit_card, debit_card, em_acount, emc_accoun...          66
# (credit_card, em_acount, emc_account, payroll_a...          63

# %%
## VIPS 5
cooc_vip_barce = cooccurrence_calculator(
    df, "revenue_class", "VIP", best_upper_plus_products, 5)
cooc_vip_barce.head(10)
# Out:
# Number of unique customers: 3141
#                                                     mean_cooccurrence  \
# product_pairs
# (credit_card, debit_card, emc_account, payroll_...               0.37
# (credit_card, debit_card, em_acount, payroll_ac...               0.06
# (debit_card, em_acount, emc_account, payroll_ac...               0.06
# (credit_card, debit_card, em_acount, emc_accoun...               0.05
# (credit_card, debit_card, em_acount, emc_accoun...               0.04
# (credit_card, em_acount, emc_account, payroll_a...               0.04
#
#                                                     user_count
# product_pairs
# (credit_card, debit_card, emc_account, payroll_...        1154
# (credit_card, debit_card, em_acount, payroll_ac...         203
# (debit_card, em_acount, emc_account, payroll_ac...         186
# (credit_card, debit_card, em_acount, emc_accoun...         159
# (credit_card, debit_card, em_acount, emc_accoun...         128
# (credit_card, em_acount, emc_account, payroll_a...         121

# %%
## VIPS 4
cooc_vip_barce = cooccurrence_calculator(
    df, "revenue_class", "VIP", best_upper_plus_products, 4)
cooc_vip_barce.head(10)
# Out:
# Number of unique customers: 3141
#                                                     mean_cooccurrence  \
# product_pairs
# (credit_card, debit_card, payroll_account, pens...               0.63
# (debit_card, emc_account, payroll_account, pens...               0.50
# (credit_card, debit_card, emc_account, payroll_...               0.38
# (credit_card, emc_account, payroll_account, pen...               0.38
# (credit_card, debit_card, emc_account, pension_...               0.37
# (debit_card, em_acount, payroll_account, pensio...               0.10
# (debit_card, em_acount, emc_account, pension_plan)               0.09
# (credit_card, debit_card, em_acount, pension_plan)               0.08
# (credit_card, debit_card, em_acount, emc_account)                0.08
# (credit_card, debit_card, em_acount, payroll_ac...               0.07
#
#                                                     user_count
# product_pairs
# (credit_card, debit_card, payroll_account, pens...        1971
# (debit_card, emc_account, payroll_account, pens...        1585
# (credit_card, debit_card, emc_account, payroll_...        1184
# (credit_card, emc_account, payroll_account, pen...        1183
# (credit_card, debit_card, emc_account, pension_...        1172
# (debit_card, em_acount, payroll_account, pensio...         314
# (debit_card, em_acount, emc_account, pension_plan)         269
# (credit_card, debit_card, em_acount, pension_plan)         259
# (credit_card, debit_card, em_acount, emc_account)          253
# (credit_card, debit_card, em_acount, payroll_ac...         213

# %%
## HIGH 5
cooc_high_barce = cooccurrence_calculator(
    df, "revenue_class", "high", best_upper_plus_products, 5)
cooc_high_barce.head(10)
# Out:
# Number of unique customers: 9865
#                                                     mean_cooccurrence  \
# product_pairs
# (credit_card, debit_card, emc_account, payroll_...               0.03
# (debit_card, em_acount, emc_account, payroll_ac...               0.01
# (credit_card, debit_card, em_acount, payroll_ac...               0.01
# (credit_card, debit_card, em_acount, emc_accoun...               0.00
# (credit_card, debit_card, em_acount, emc_accoun...               0.00
# (credit_card, em_acount, emc_account, payroll_a...               0.00
#
#                                                     user_count
# product_pairs
# (credit_card, debit_card, emc_account, payroll_...         338
# (debit_card, em_acount, emc_account, payroll_ac...         123
# (credit_card, debit_card, em_acount, payroll_ac...          73
# (credit_card, debit_card, em_acount, emc_accoun...          45
# (credit_card, debit_card, em_acount, emc_accoun...          36
# (credit_card, em_acount, emc_account, payroll_a...          23

# %%
## HIGH 4
cooc_high_barce = cooccurrence_calculator(
    df, "revenue_class", "high", best_upper_plus_products, 4)
cooc_high_barce.head(10)
# Out:
# Number of unique customers: 9865
#                                                     mean_cooccurrence  \
# product_pairs
# (debit_card, emc_account, payroll_account, pens...               0.17
# (credit_card, debit_card, payroll_account, pens...               0.12
# (credit_card, debit_card, emc_account, payroll_...               0.05
# (credit_card, emc_account, payroll_account, pen...               0.04
# (debit_card, em_acount, payroll_account, pensio...               0.04
# (credit_card, debit_card, em_acount, emc_account)                0.04
# (credit_card, debit_card, emc_account, pension_...               0.04
# (debit_card, em_acount, emc_account, pension_plan)               0.03
# (debit_card, em_acount, emc_account, payroll_ac...               0.01
# (em_acount, emc_account, payroll_account, pensi...               0.01
#
#                                                     user_count
# product_pairs
# (debit_card, emc_account, payroll_account, pens...        1649
# (credit_card, debit_card, payroll_account, pens...        1195
# (credit_card, debit_card, emc_account, payroll_...         485
# (credit_card, emc_account, payroll_account, pen...         431
# (debit_card, em_acount, payroll_account, pensio...         419
# (credit_card, debit_card, em_acount, emc_account)          360
# (credit_card, debit_card, emc_account, pension_...         359
# (debit_card, em_acount, emc_account, pension_plan)         294
# (debit_card, em_acount, emc_account, payroll_ac...         143
# (em_acount, emc_account, payroll_account, pensi...         131

# %%
## HIGH 3
cooc_high_barce = cooccurrence_calculator(
    df, "revenue_class", "high", best_upper_plus_products, 3)
cooc_high_barce.head(10)
# Out:
# Number of unique customers: 9865
#                                               mean_cooccurrence  user_count
# product_pairs
# (debit_card, payroll_account, pension_plan)                0.71        6969
# (emc_account, payroll_account, pension_plan)               0.19        1875
# (debit_card, emc_account, payroll_account)                 0.18        1823
# (debit_card, emc_account, pension_plan)                    0.18        1734
# (credit_card, debit_card, payroll_account)                 0.15        1467
# (credit_card, payroll_account, pension_plan)               0.14        1394
# (credit_card, debit_card, pension_plan)                    0.12        1230
# (debit_card, em_acount, pension_plan)                      0.11        1039
# (debit_card, em_acount, emc_account)                       0.10         989
# (credit_card, debit_card, em_acount)                       0.09         854

# %% [markdown]
# ## CONCLUSION:
#
# Customers with high + retention and high + revenue majorly have debit_card, payroll_account and pension_plan.
# The next missing product in order to get to VIP level is a credit_card.
#
# → find customers that have no credit card yet, but active debit_card, payroll_account and pension_plan throughout 3 most recent months.
# → take the top 10000k

# %%
df_last_3m = df[df["pk_partition"] > "2019-03-01"]
df_last_3m["pk_cid"].nunique()
# Out:
# 445397

# %%
output = df_last_3m.groupby("pk_cid")["debit_card", "payroll_account", "pension_plan", "credit_card"].sum()

# filter the rows based on the conditions
filtered_output = output[(output["credit_card"] == 0) & 
                         (((output["debit_card"] > 2) & (output["pension_plan"] > 2)) |
                          ((output["debit_card"] > 2) & (output["payroll_account"] > 2)) |
                          ((output["payroll_account"] > 2) & (output["pension_plan"] > 2)))]

filtered_output["highest_retention"] = filtered_output.sum(axis = 1)
filtered_output.sort_values("highest_retention", ascending = False, inplace = True)

# %%
best_10000_for_credit_card = filtered_output.head(10000)
best_10000_for_credit_card
# Out:
#          debit_card  payroll_account  pension_plan  credit_card  \
# pk_cid
# 1380909           3                3             3            0
# 1217423           3                3             3            0
# 1218102           3                3             3            0
# 1218083           3                3             3            0
# 1443608           3                3             3            0
# ...             ...              ...           ...          ...
# 1400070           3                3             0            0
# 1400053           3                3             0            0
# 1400031           3                3             0            0
# 1399982           0                3             3            0
# 1399978           0                3             3            0
#
#          highest_retention
# pk_cid
# 1380909                  9
# 1217423                  9
# 1218102                  9
# 1218083                  9
# 1443608                  9
# ...                    ...
# 1400070                  6
# 1400053                  6
# 1400031                  6
# 1399982                  6
# 1399978                  6
#
# [10000 rows x 5 columns]
